# %%
import os
os.getcwd()
# Out:
# '/Users/ryan/Documents/pandas-cookbook/cookbook'

# %%
import pandas as pd
import sqlite3
weather_df = pd.read_csv('../PokerDataFACET/session7a2/FACET_emotient_new.csv')
con = sqlite3.connect("../facet.db")
con.execute("DROP TABLE IF EXISTS weather_2012")
weather_df.to_sql("session7a2", con)
# Out:
# /Applications/Anaconda3/anaconda/lib/python3.4/site-packages/pandas/io/sql.py:1371: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   warnings.warn(_SAFE_NAMES_WARNING)

# %%
import csv
import sqlite3
import glob
import os
import pandas as pd


con = sqlite3.connect("../facet.db")

import os
root_path = os.getcwd() + "/../PokerDataFACET"

dirs = os.listdir(root_path)
count = 0
check_file = "java_framedata.txt"
read_file = "FACET_emotient_new.csv"
for files in dirs:  # files = folder name
    #path = os.path.join(root_path,files)
    if files[0] == '.':
        continue
    print(path)
    if check_file in os.listdir(path):
        with open(os.path.join(path,check_file), 'r') as check:
            for line in check:
                l = line.strip().split(',')
                if len(l) > 3:
                    if l[3] == 'poker':
                        with open(os.path.join(path,read_file), 'r') as read: # abs path to FACET_emotient_new.csv
                            #print("Reading poker file")
                            weather_df = pd.read_csv(read)
                            #weather_df.to_sql(files, con)
                        count += 1


print(count)
# Out:
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session74
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session74a
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session74b
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session74d
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session750
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session753
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session754
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session755
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session758
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session75b
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session75c
# Reading poker file
# ...

# %%
# create header table - does not work
import csv
import sqlite3
import glob
import os
import pandas as pd


con = sqlite3.connect("../facet.db")

c = conn.cursor()

# Create table
c.execute('''\
CREATE TABLE "header" (
“sessionID” TEXT,
  "opponentID" INTEGER,
  "score" INTEGER,
  "foldCount" INTEGER,
  "callCount" INTEGER,
  "raiseCount" INTEGER,
  "bluffCount" INTEGER,
  "participantID" INTEGER,
  "startTime-minTime" INTEGER,
  "opponentSession" TEXT,
  "gameType" TEXT,
  "answers0" TEXT,
  "answers1" TEXT,
  "answers2" TEXT,
  "answerResults0" TEXT,
  "answerResults1" TEXT,
  "answerResults2" TEXT
)''')
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-53-4a40d792eb42> in <module>()
#      12
#      13 # Create table
# ---> 14 c.execute('''CREATE TABLE "header" ( “sessionID” TEXT,  "opponentID" INTEGER,  "score" INTEGER,  "foldCount" INTEGER,  "callCount" INTEGER,  "raiseCount" INTEGER,  "bluffCount" INTEGER,  "participantID" INTEGER,  "startTime-minTime" INTEGER,  "opponentSession" TEXT,  "gameType" TEXT,  "answers0" TEXT,  "answers1" TEXT,  "answers2" TEXT,  "answerResults0" TEXT,  "answerResults1" TEXT,  "answerResults2" TEXT)''')
#      15 conn.commit()
#
# OperationalError: table "header" already exists

# %%
# add header data
import csv
import sqlite3
import glob
import os
import pandas as pd


conn = sqlite3.connect('../facet.db')
c = conn.cursor()
root_path = os.getcwd() + "/../PokerDataFACET"

dirs = os.listdir(root_path)
count = 0
check_file = "java_framedata.txt"
read_file = "Combined_game_frame_data.txt"
for files in dirs:  # files = folder name
    path = os.path.join(root_path,files)
    if files[0] == '.':
        continue
    #print(path)
    if check_file in os.listdir(path):
        with open(os.path.join(path,check_file), 'r') as check:
            for line in check:
                l = line.strip().split(',')
                if len(l) > 3:
                    if l[3] == 'poker':
                        with open(os.path.join(path,read_file), 'r') as read:
                            #print("Reading poker file")
                            reader = csv.reader(read,delimiter=',')
                            for row in reader:
                                to_db = []
                                to_db.append(files[7:])
                                for element in row:
                                    to_db.append(element)
                                
                                #c.execute("INSERT INTO header VALUES(%s);" % ','.join('?' * len(to_db)), to_db )

                        count += 1
conn.commit()
print(count)
# Out:
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session74
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session74a
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session74b
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session74d
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session750
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session753
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session754
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session755
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session758
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session75b
# Reading poker file
# /Users/ryan/Documents/pandas-cookbook/cookbook/../PokerDataFACET/session75c
# Reading poker file
# ...

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
con = sqlite3.connect("../facet.db")
df = pd.read_sql("SELECT * from session7a3 limit 3", con, 
                 index_col='Frametime')
df
# Out:
#            index  Face X  Face Y  Face Width  Face Height  angerEvidence  contemptEvidence  disgustEvidence  joyEvidence  fearEvidence  negativeEvidence  neutralEvidence  positiveEvidence  sadnessEvidence  surpriseEvidence  confusionEvidence  frustrationEvidence  angerIntensity  contemptIntensity  disgustIntensity  joyIntensity  fearIntensity  negativeIntensity  neutralIntensity  positiveIntensity  sadnessIntensity  surpriseIntensity  confusionIntensity  frustrationIntensity  AU1Evidence  AU2Evidence  AU4Evidence  AU5Evidence  AU6Evidence  AU7Evidence  AU9Evidence  AU10Evidence  AU12Evidence  AU14Evidence  AU15Evidence  AU17Evidence  AU18Evidence  AU20Evidence  AU23Evidence  AU24Evidence  AU25Evidence  AU26Evidence  AU28Evidence
# Frametime
# ...

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
con = sqlite3.connect("../facet.db")
df = pd.read_sql("SELECT * from session7a3", con, 
                 index_col='Frametime')
df['angerEvidence'].plot()
